# %% [markdown]
# # AI Health Sync Notebook
#
# Environment setup and dependency installation.

# %%
# Install all dependencies
# !pip install flask pyngrok tensorflow scikit-learn pandas numpy nltk

# %% [markdown]
# ### 1.5 Download NLTK data: punkt, wordnet, omw-1.4

# %%
import nltk

# Download required NLTK datasets
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
